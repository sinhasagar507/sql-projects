# %% [markdown]
# #### Assignment 5: Geographic Data Analysis
#
# In this assignment, you will be using a database of geographic data provided for you in the PySal library to create two plots, a choropleth map and a proportional symbol map. In addition to these two plots, you will compute the value of Moran's I for this data.
#
# #### Dataset
#
# The dataset to be used in this assignment is a dataset containing Per Capita incomes for the United States' lower 48 states. In addition to the state-by-state data, the dataset contains shape files for each state that you can use
# to create the choropleth and proportional symbol maps.
#
# #### Administrative Notes
#
# This assignment will be graded by Coursera's grading system. In order for your answers to be correctly registered in the system, you must place the code for your answers in the cell indicated for each question. In addition, you should submit the assignment with the output of the code in the cell's display area. The display area should contain only your answer to the question with no extraneous information, or else the answer may not be picked up correctly. Each cell that is going to be graded has a set of comment lines at the beginning of the cell. These lines are extremely important and must not be modified or removed.

# %%
# Install the necessary libraries 
# !pip install pysal
# Out:
# Requirement already satisfied: pysal in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (24.7)
# Requirement already satisfied: beautifulsoup4>=4.10 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (4.12.3)
# Requirement already satisfied: geopandas>=0.10.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (1.26.4)
# Requirement already satisfied: packaging>=22 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (24.1)
# Requirement already satisfied: pandas>=1.4 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (2.2.2)
# Requirement already satisfied: platformdirs>=2.0.2 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (3.10.0)
# Requirement already satisfied: requests>=2.27 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (2.32.3)
# Requirement already satisfied: scipy>=1.8 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (1.14.1)
# Requirement already satisfied: shapely>=2.0.1 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (2.0.6)
# Requirement already satisfied: scikit-learn>=1.1 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (1.6.0)
# Requirement already satisfied: libpysal>=4.12.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (4.12.1)
# Requirement already satisfied: access>=1.1.9 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (1.1.9)
# Requirement already satisfied: esda>=2.6.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (2.6.0)
# Requirement already satisfied: giddy>=2.3.5 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (2.3.6)
# Requirement already satisfied: inequality>=1.0.1 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (1.0.1)
# Requirement already satisfied: pointpats>=2.5.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (2.5.1)
# Requirement already satisfied: segregation>=2.5 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (2.5.1)
# Requirement already satisfied: spaghetti>=1.7.6 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (1.7.6)
# Requirement already satisfied: mgwr>=2.2.1 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (2.2.1)
# Requirement already satisfied: momepy>=0.7.2 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (0.9.1)
# Requirement already satisfied: spglm>=1.1.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (1.1.0)
# Requirement already satisfied: spint>=1.0.7 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (1.0.7)
# Requirement already satisfied: spreg>=1.5.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (1.8.1)
# Requirement already satisfied: spvcm>=0.3.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (0.3.0)
# Requirement already satisfied: tobler>=0.11.2 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (0.12.0)
# Requirement already satisfied: mapclassify>=2.7.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (2.8.1)
# Requirement already satisfied: splot>=1.1.5.post1 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (1.1.7)
# Requirement already satisfied: spopt>=0.6.1 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pysal) (0.6.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from beautifulsoup4>=4.10->pysal) (2.5)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from geopandas>=0.10.0->pysal) (0.10.0)
# Requirement already satisfied: pyproj>=3.3.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from geopandas>=0.10.0->pysal) (3.7.0)
# Requirement already satisfied: quantecon>=0.7 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from giddy>=2.3.5->pysal) (0.7.2)
# Requirement already satisfied: networkx>=2.7 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from mapclassify>=2.7.0->pysal) (3.4.2)
# Requirement already satisfied: tqdm>=4.63.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from momepy>=0.7.2->pysal) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pandas>=1.4->pysal) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pandas>=1.4->pysal) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pandas>=1.4->pysal) (2023.3)
# Requirement already satisfied: matplotlib>=3.6 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from pointpats>=2.5.0->pysal) (3.9.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests>=2.27->pysal) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests>=2.27->pysal) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests>=2.27->pysal) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from requests>=2.27->pysal) (2024.8.30)
# Requirement already satisfied: joblib>=1.2.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from scikit-learn>=1.1->pysal) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from scikit-learn>=1.1->pysal) (3.5.0)
# Requirement already satisfied: deprecation in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from segregation>=2.5->pysal) (2.1.0)
# Requirement already satisfied: seaborn in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from segregation>=2.5->pysal) (0.13.2)
# Requirement already satisfied: numba in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from segregation>=2.5->pysal) (0.60.0)
# Requirement already satisfied: rtree>=1.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from spaghetti>=1.7.6->pysal) (1.3.0)
# Requirement already satisfied: pulp>=2.7 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from spopt>=0.6.1->pysal) (2.9.0)
# Requirement already satisfied: rasterio in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from tobler>=0.11.2->pysal) (1.4.3)
# Requirement already satisfied: statsmodels in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from tobler>=0.11.2->pysal) (0.14.4)
# Requirement already satisfied: rasterstats in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from tobler>=0.11.2->pysal) (0.20.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=3.6->pointpats>=2.5.0->pysal) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=3.6->pointpats>=2.5.0->pysal) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=3.6->pointpats>=2.5.0->pysal) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=3.6->pointpats>=2.5.0->pysal) (1.4.4)
# Requirement already satisfied: pillow>=8 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=3.6->pointpats>=2.5.0->pysal) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib>=3.6->pointpats>=2.5.0->pysal) (3.2.0)
# Requirement already satisfied: six>=1.5 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.4->pysal) (1.16.0)
# Requirement already satisfied: sympy in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from quantecon>=0.7->giddy>=2.3.5->pysal) (1.13.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from numba->segregation>=2.5->pysal) (0.43.0)
# Requirement already satisfied: affine in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from rasterio->tobler>=0.11.2->pysal) (2.4.0)
# Requirement already satisfied: attrs in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from rasterio->tobler>=0.11.2->pysal) (24.2.0)
# Requirement already satisfied: click>=4.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from rasterio->tobler>=0.11.2->pysal) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from rasterio->tobler>=0.11.2->pysal) (0.7.2)
# Requirement already satisfied: click-plugins in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from rasterio->tobler>=0.11.2->pysal) (1.1.1)
# Requirement already satisfied: fiona in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from rasterstats->tobler>=0.11.2->pysal) (1.10.1)
# Requirement already satisfied: simplejson in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from rasterstats->tobler>=0.11.2->pysal) (3.19.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from statsmodels->tobler>=0.11.2->pysal) (1.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/saggysimmba/Applications/miniconda3/envs/myenv/lib/python3.11/site-packages (from sympy->quantecon>=0.7->giddy>=2.3.5->pysal) (1.3.0)

# %%
import geopandas as gpd
import pysal as ps
import pandas as pd
import numpy as np
import libpysal as lps
import matplotlib.pyplot as plt
from pysal.explore import esda
from pysal.lib import weights,examples

# %%
# Graded Cell, PartID: CkcsR
# Part 1: Using the PySal Data, create a choropleth path of the United States
# that depicts the per capita income of each US state in 2009.
# Notes: The PySal and GeoPandas libraries both contain utility functions that
# may make this task easier.
per_capita_data = pd.read_csv(lps.examples.get_path("usjoin.csv"))
us_plot_df = gpd.read_file(lps.examples.get_path('us48.shx'))
us_plot_df['per_capita'] = list(per_capita_data["2009"])
plt.rcParams["figure.figsize"] = (40,8)
us_plot_df.plot(column = "per_capita")
plt.show()

# %%
# Graded Cell, PartID: FqNRm
# Part 2: Again using the PySal Data, create a proportional symbol map showing 
# a dot at the centroid of each state that is scaled to the per capita income 
# of each US state in 2009.
# Notes: The demonstration notebook for this unit contains code that performs 
# a similar task and may be a useful reference for your assignment.
us_plot_df['centroid_column'] = us_plot_df.centroid
centroids = list(us_plot_df['centroid_column'])
final_df = pd.DataFrame({'y':[centroids[i].y for i in range(len(centroids))], \
                   'x':[centroids[i].x for i in range(len(centroids))], \
                   'data':list(us_plot_df['per_capita'])})
base = us_plot_df.plot(color='white', edgecolor='black')
plt.rcParams["figure.figsize"] = (40,8)
final_df.plot( kind='scatter', x='x', y='y', s=final_df['data']*0.01, ax=base)
plt.show()

# %%
# Graded Cell, PartID: CtQYv
# Part 3: Using the same data, compute the value of Moran's I for the per 
# capita income of each US state in 2009 using Rook Continuity. Report the 
# value of I rounded to 4 decimal places (i.e. x.XXXX)
# Notes: Again, the PySal and GeoPandas libraries may contain useful utility
# functions.
y = us_plot_df['per_capita']
w = weights.Rook.from_shapefile(examples.get_path("us48.shx"))
moran_stat = esda.Moran(y,w, two_tailed=False)
print (round(moran_stat.I, 4))
# Out:
# 0.0407
